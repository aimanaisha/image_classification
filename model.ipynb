# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img = cv2.imread('./test_img/1.jpg')
img.shape
# Out:
# (3840, 2560, 3)

# %%
plt.imshow(img)
